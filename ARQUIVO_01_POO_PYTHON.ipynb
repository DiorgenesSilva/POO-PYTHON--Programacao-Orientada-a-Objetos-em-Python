# %% [markdown]
# <a href="https://colab.research.google.com/github/DiorgenesSilva/POO-PYTHON--Programacao-Orientada-a-Objetos-em-Python/blob/main/ARQUIVO_01_POO_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **PROGRAMAÇÃO ORIENTADA A OBJETO (POO) COM PYTHON**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Declaração da Classe
# class MinhaClasse:
#     #Atributos da Classe
#
#     #Metodos da Calsse
#
# # Declaração dos Objetos
# obj = MinhaClasse()
